# %%
import pandas as pd

# %%
df=pd.read_csv('.\datasets\HR_comma_sep.csv')

# %%
df.head(500)
# Out:
#      satisfaction_level  last_evaluation  number_project  \
# 0                  0.38             0.53               2
# 1                  0.80             0.86               5
# 2                  0.11             0.88               7
# 3                  0.72             0.87               5
# 4                  0.37             0.52               2
# ..                  ...              ...             ...
# 495                0.82             0.99               4
# 496                0.10             0.82               6
# 497                0.59             0.49               7
# 498                0.44             0.48               2
# 499                0.89             0.95               2
#
#      average_montly_hours  time_spend_company  Work_accident  left  \
# 0                     157                   3              0     1
# 1                     262                   6              0     1
# 2                     272                   4              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.size
# Out:
# 149990

# %%
df.loc[10:20]
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 10                0.45             0.54               2                   135
# 11                0.11             0.81               6                   305
# 12                0.84             0.92               4                   234
# 13                0.41             0.55               2                   148
# 14                0.36             0.56               2                   137
# 15                0.38             0.54               2                   143
# 16                0.45             0.47               2                   160
# 17                0.78             0.99               4                   255
# 18                0.45             0.51               2                   160
# 19                0.76             0.89               5                   262
# 20                0.11             0.83               6                   282
#
# ...

# %%
#to show department where sales
a=df["Department"]
count=0
for i in a:
    if i=="sales":
        count=count+1
print(count)
# Out:
# 4140

# %%
#finding who works more than 200 hrs in avg monthly hrs
a=df["average_montly_hours"]
count=0
for i in a:
    if i>200:
        count=count+1
print(count)
# Out:
# 7475

# %%
#create a new column
#df['']=

# %%
#inserting a row 
#newr=pd.DataFrame{dictionary}
#df.concat(newr,df)

# %%
#inserting a row using iloc{it will replace the data in the particular  index}
#df.iloc[-1]=['xyz,'zyz'zyz]

# %%
#deleting a column
#df.drop("column",axis=1,inplace=True)

# %%
#deleting a column
#df.drop[index]

# %%
#calling index and deleting specific row 
#df.drop(df.index[#index],inplace=True)

# %%
#deleting rows based on specific postion
#df=df[:]

# %%
#deleting duplicates
#df.drop duplicates()

# %%
#findout which movies has runtime greater than 150
#findout duplicate and remove
#

# %%
import pandas as pd
data=pd.read_csv('movies.csv',encoding='latin1')
data.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# ...

# %%
movies_more_than_150_hrs=data[['original_title']][data['runtime']>150]

# %%
movies_more_than_150_hrs.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_206d0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >original_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_206d0_row0_col0" class="data row0 col0" >Heat</td>
#     </tr>
#     <tr>
#       <td id="T_206d0_row1_col0" class="data row1 col0" >Nixon</td>
#     </tr>
#     <tr>
#       <td id="T_206d0_row2_col0" class="data row2 col0" >Casino</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(movies_more_than_150_hrs)
# Out:
# 3

# %%
data.shape
# Out:
# (50, 24)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
data1=data.drop_duplicates()

# %%
data1.shape
# Out:
# (50, 24)

# %% [markdown]
# **since there are no duplicates the number of rows remain same**
